# %%
from ultralytics import YOLO

model = YOLO("yolo26n-seg.pt")

results = model.train(
    data="/Users/mac/MeterReadAI/data/Word_Wheel_Water_Meter/data.yaml",
    epochs=1,
    imgsz=640,
    batch=16,
    device="mps",
    workers=4,
    project="runs/meter",
    name="yolov12n_seg_test"
)
# Out:
# New https://pypi.org/project/ultralytics/8.4.120 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.117 🚀 Python-3.11.9 torch-2.13.0 MPS (Apple M4)
# ...
